# %% [markdown]
# ### Overview of the notebook
#
# 1. [Data Cleaning](#chapter1)<br>
#    1.1 [NYC Housing Sales Data](#section_1_1)<br>
#    1.2 [NYC 311 Service Requests](#section_1_2)<br>
#    1.3 [NYC Quality of Drinking Water data](#section_1_3)<br>
#    1.4 [NYC Merging all Dataframes](#section_1_4)<br>

# %% [markdown]
# # Data Cleaning <a class="anchor" id="chapter1"></a>

# %% [markdown]
# We use three databases to understand the prioritization of water-related problems in New York City. In general, we are analyzing 5 years of data containing market value per zip code, complaints per zip code, and water quality.

# %% [markdown]
# **Datasets sources**

# %% [markdown]
# **1)** [NYC Rolling sales](https://www1.nyc.gov/site/finance/taxes/property-annualized-sales-update.page)
#
# **2)** [Drinkable water quality](https://data.cityofnewyork.us/Environment/Drinking-Water-Quality-Distribution-Monitoring-Dat/bkwf-xfky)
#
# **3)** [311 service requests](https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9)

# %%
#loading libraries
import pandas as pd
import glob
import datetime

# %% [markdown]
# ## NYC Housing Sales Data <a class="anchor" id="section_1_1"></a>

# %% [markdown]
# This section of the cleanup is destined to extract the annual sales data in the 5 regions of the city from 2010 to 2021, in total we have **55 CSV files to join and aggregate** in order to analyze the evolution of the house prices in the region.
#
# The source of all the data is at this link:
# https://www1.nyc.gov/site/finance/taxes/property-annualized-sales-update.page

# %% [markdown]
# **2010 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2010_*.xls')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [3]), all_files)
li_2 = list(li_mapper)
df_2010 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2010.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        2  BATHGATE
# 1        2  BATHGATE
# 2        2  BATHGATE
# 3        2  BATHGATE
# 4        2  BATHGATE
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1   3030
# 1  01  ONE FAMILY HOMES                                            1   3035
# 2  01  ONE FAMILY HOMES                                            1   3037
# 3  01  ONE FAMILY HOMES                                            1   3039
# 4  01  ONE FAMILY HOMES                                            1   3046
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   70                                  A1
# 1    2                                  S1
# 2   42                                  A1
# 3   64                                  A1
# 4   34                                  A1
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  4445 PARK AVENUE                                            ...
# 1  441 EAST 178 STREET                                         ...
# 2  4428 PARK AVENUE                                            ...
# 3  467 EAST 185 STREET                                         ...
# 4  2085 BATHGATE AVENUE                                        ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 0            1              1694
# 1                  1                 1            2              1287
# 2                  1                 0            1              3525
# 3                  1                 0            1              1667
# 4                  1                 0            1              2060
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               1497        1899                          1
# 1               2378        1899                          1
# 2               1340        1899                          1
# 3               1296        1910                          1
# 4               1629        1899                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              A1          0 2010-01-15
# 1                              S1     116000 2010-07-01
# 2                              A1     287000 2010-12-10
# 3                              A1     150000 2010-04-20
# 4                              A1     145915 2010-07-27
#
# [5 rows x 21 columns]

# %%
#checking null values by columns
df_2010.isnull().mean() * 100
# Out:
# BOROUGH                           0.0
# NEIGHBORHOOD                      0.0
# BUILDING CLASS CATEGORY           0.0
# TAX CLASS AT PRESENT              0.0
# BLOCK                             0.0
# LOT                               0.0
# EASE-MENT                         0.0
# BUILDING CLASS AT PRESENT         0.0
# ADDRESS                           0.0
# APARTMENT NUMBER                  0.0
# ZIP CODE                          0.0
# RESIDENTIAL UNITS                 0.0
# COMMERCIAL UNITS                  0.0
# TOTAL UNITS                       0.0
# LAND SQUARE FEET                  0.0
# GROSS SQUARE FEET                 0.0
# YEAR BUILT                        0.0
# TAX CLASS AT TIME OF SALE         0.0
# BUILDING CLASS AT TIME OF SALE    0.0
# SALE PRICE                        0.0
# SALE DATE                         0.0
# dtype: float64

# %% [markdown]
# **2011 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2011_*.xls')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [4]), all_files)
li_2 = list(li_mapper)
df_2011 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2011.columns = df_2010.columns
df_2011.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1    376
# 1  02  TWO FAMILY HOMES                                            1    373
# 2  07  RENTALS - WALKUP APARTMENTS                                2A    372
# 3  07  RENTALS - WALKUP APARTMENTS                                 2    376
# 4  07  RENTALS - WALKUP APARTMENTS                                 2    377
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   43                                  S1
# 1    1                                  S2
# 2   31                                  C3
# 3   54                                  C4
# 4    2                                  C7
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  743 EAST 6TH   STREET                                       ...
# 1  40 AVENUE C                                                 ...
# 2  316 EAST 3RD   STREET                                       ...
# 3  719 E 6TH  ST                                               ...
# 4  116 AVENUE C                                                ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 1            2              2090
# 1                  2                 1            3              1923
# 2                  4                 0            4              5746
# 3                 16                 0           16              3437
# 4                 22                 3           25              4510
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               3680        1940                          1
# 1               4800        1901                          1
# 2               2700        1900                          2
# 3               9180        1900                          2
# 4              19830        1900                          2
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              S1         10 2011-08-26
# 1                              S2          0 2011-12-21
# 2                              C3    3500000 2011-09-08
# 3                              C4    2966835 2011-07-25
# 4                              C7          0 2011-06-10
#
# [5 rows x 21 columns]

# %%
#checking null values by columns
df_2011.isnull().mean() * 100
# Out:
# BOROUGH                           0.0
# NEIGHBORHOOD                      0.0
# BUILDING CLASS CATEGORY           0.0
# TAX CLASS AT PRESENT              0.0
# BLOCK                             0.0
# LOT                               0.0
# EASE-MENT                         0.0
# BUILDING CLASS AT PRESENT         0.0
# ADDRESS                           0.0
# APARTMENT NUMBER                  0.0
# ZIP CODE                          0.0
# RESIDENTIAL UNITS                 0.0
# COMMERCIAL UNITS                  0.0
# TOTAL UNITS                       0.0
# LAND SQUARE FEET                  0.0
# GROSS SQUARE FEET                 0.0
# YEAR BUILT                        0.0
# TAX CLASS AT TIME OF SALE         0.0
# BUILDING CLASS AT TIME OF SALE    0.0
# SALE PRICE                        0.0
# SALE DATE                         0.0
# dtype: float64

# %% [markdown]
# **2012 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2012_*.xls')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [4]), all_files)
li_2 = list(li_mapper)
df_2012 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2012.columns = df_2010.columns
df_2012.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  03  THREE FAMILY HOMES                                          1    377
# 1  07  RENTALS - WALKUP APARTMENTS                                 2    375
# 2  07  RENTALS - WALKUP APARTMENTS                                 2    376
# 3  07  RENTALS - WALKUP APARTMENTS                                2A    377
# 4  07  RENTALS - WALKUP APARTMENTS                                 2    387
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   10                                  C0
# 1   62                                  C4
# 2   30                                  C4
# 3   52                                  C2
# 4  157                                  C1
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  356 EAST 8TH STREET                                         ...
# 1  715 EAST 5TH   STREET                                       ...
# 2  274 EAST SEVENTH STREET                                     ...
# 3  271 EAST 7TH   STREET                                       ...
# 4  619 EAST 5TH   STREET                                       ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  3                 0            3              1804
# 1                 20                 0           20              2426
# 2                 13                 0           13              2726
# 3                  5                 0            5              2169
# 4                 40                 0           40              4853
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               2928        1899                          1
# 1               9345        1900                          2
# 2              13002        1910                          2
# 3               3728        1900                          2
# 4              25200        1900                          2
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              C0          0 2012-07-09
# 1                              C4    3650000 2012-09-06
# 2                              C4     895250 2012-10-25
# 3                              C2          0 2012-02-16
# 4                              C1   10800000 2012-07-13
#
# [5 rows x 21 columns]

# %%
#checking null values by columns
df_2012.isnull().mean() * 100
# Out:
# BOROUGH                           0.0
# NEIGHBORHOOD                      0.0
# BUILDING CLASS CATEGORY           0.0
# TAX CLASS AT PRESENT              0.0
# BLOCK                             0.0
# LOT                               0.0
# EASE-MENT                         0.0
# BUILDING CLASS AT PRESENT         0.0
# ADDRESS                           0.0
# APARTMENT NUMBER                  0.0
# ZIP CODE                          0.0
# RESIDENTIAL UNITS                 0.0
# COMMERCIAL UNITS                  0.0
# TOTAL UNITS                       0.0
# LAND SQUARE FEET                  0.0
# GROSS SQUARE FEET                 0.0
# YEAR BUILT                        0.0
# TAX CLASS AT TIME OF SALE         0.0
# BUILDING CLASS AT TIME OF SALE    0.0
# SALE PRICE                        0.0
# SALE DATE                         0.0
# dtype: float64

# %% [markdown]
# **2013 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2013_*.xls')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [4]), all_files)
li_2 = list(li_mapper)
df_2013 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2013.columns = df_2010.columns
df_2013.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        3  BATH BEACH
# 1        3  BATH BEACH
# 2        3  BATH BEACH
# 3        3  BATH BEACH
# 4        3  BATH BEACH
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY DWELLINGS                                        1   6360
# 1  01  ONE FAMILY DWELLINGS                                        1   6360
# 2  01  ONE FAMILY DWELLINGS                                        1   6361
# 3  01  ONE FAMILY DWELLINGS                                        1   6361
# 4  01  ONE FAMILY DWELLINGS                                        1   6363
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   50                                  A5
# 1   67                                  A5
# 2   14                                  A5
# 3   21                                  A5
# 4   23                                  A9
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  18 BAY 10TH   STREET                                        ...
# 1  56 BAY 10TH STREET                                          ...
# 2  63 BAY 10TH   STREET                                        ...
# 3  45 BAY 10TH   STREET                                        ...
# 4  8641 16TH AVENUE                                            ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 0            1              1547
# 1                  1                 0            1              1547
# 2                  1                 0            1              1933
# 3                  1                 0            1              1933
# 4                  1                 0            1              2058
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               1428        1930                          1
# 1               1428        1930                          1
# 2               1660        1930                          1
# 3               1660        1930                          1
# 4               1492        1930                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              A5     505000 2013-09-05
# 1                              A5     690000 2013-11-19
# 2                              A5     638000 2013-10-04
# 3                              A5     729000 2013-09-26
# 4                              A9     560000 2013-06-06
#
# [5 rows x 21 columns]

# %%
#checking null values by columns
df_2013.isnull().mean() * 100
# Out:
# BOROUGH                           0.0
# NEIGHBORHOOD                      0.0
# BUILDING CLASS CATEGORY           0.0
# TAX CLASS AT PRESENT              0.0
# BLOCK                             0.0
# LOT                               0.0
# EASE-MENT                         0.0
# BUILDING CLASS AT PRESENT         0.0
# ADDRESS                           0.0
# APARTMENT NUMBER                  0.0
# ZIP CODE                          0.0
# RESIDENTIAL UNITS                 0.0
# COMMERCIAL UNITS                  0.0
# TOTAL UNITS                       0.0
# LAND SQUARE FEET                  0.0
# GROSS SQUARE FEET                 0.0
# YEAR BUILT                        0.0
# TAX CLASS AT TIME OF SALE         0.0
# BUILDING CLASS AT TIME OF SALE    0.0
# SALE PRICE                        0.0
# SALE DATE                         0.0
# dtype: float64

# %% [markdown]
# **2014 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2014_*.xls')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [4]), all_files)
li_2 = list(li_mapper)
df_2014 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2014.columns = df_2010.columns
df_2014.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        5  ANNADALE
# 1        5  ANNADALE
# 2        5  ANNADALE
# 3        5  ANNADALE
# 4        5  ANNADALE
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY DWELLINGS                                        1   5391
# 1  01  ONE FAMILY DWELLINGS                                        1   5391
# 2  01  ONE FAMILY DWELLINGS                                        1   5399
# 3  01  ONE FAMILY DWELLINGS                                        1   5406
# 4  01  ONE FAMILY DWELLINGS                                        1   5406
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   13                                  A5
# 1   65                                  A3
# 2    7                                  A2
# 3    1                                  A1
# 4   11                                  A1
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  4716 AMBOY ROAD                                             ...
# 1  22 BLUE HERON DRIVE                                         ...
# 2  24 SANDBORN STREET                                          ...
# 3  381 HAROLD AVENUE                                           ...
# 4  168 KINGHORN STREET                                         ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 0            1              1871
# 1                  1                 0            1              8000
# 2                  1                 0            1              4750
# 3                  1                 0            1              9900
# 4                  1                 0            1             10000
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               1110        2002                          1
# 1               3800        1987                          1
# 2               2002        1960                          1
# 3               1768        1940                          1
# 4               2600        1920                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              A5     370000 2014-12-08
# 1                              A3          0 2014-07-17
# 2                              A2          0 2014-05-30
# 3                              A1     740000 2014-07-29
# 4                              A1          0 2014-06-17
#
# [5 rows x 21 columns]

# %%
#checking null values by columns
df_2014.isnull().mean() * 100
# Out:
# BOROUGH                           0.0
# NEIGHBORHOOD                      0.0
# BUILDING CLASS CATEGORY           0.0
# TAX CLASS AT PRESENT              0.0
# BLOCK                             0.0
# LOT                               0.0
# EASE-MENT                         0.0
# BUILDING CLASS AT PRESENT         0.0
# ADDRESS                           0.0
# APARTMENT NUMBER                  0.0
# ZIP CODE                          0.0
# RESIDENTIAL UNITS                 0.0
# COMMERCIAL UNITS                  0.0
# TOTAL UNITS                       0.0
# LAND SQUARE FEET                  0.0
# GROSS SQUARE FEET                 0.0
# YEAR BUILT                        0.0
# TAX CLASS AT TIME OF SALE         0.0
# BUILDING CLASS AT TIME OF SALE    0.0
# SALE PRICE                        0.0
# SALE DATE                         0.0
# dtype: float64

# %% [markdown]
# **2015 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2015_*.xls')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [4]), all_files)
li_2 = list(li_mapper)
df_2015 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2015.columns = df_2010.columns
df_2015.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        1  ALPHABET CITY
# 1        1  ALPHABET CITY
# 2        1  ALPHABET CITY
# 3        1  ALPHABET CITY
# 4        1  ALPHABET CITY
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY DWELLINGS                                        1    400
# 1  03  THREE FAMILY DWELLINGS                                      1    376
# 2  03  THREE FAMILY DWELLINGS                                      1    377
# 3  04  TAX CLASS 1 CONDOS                                         1C    399
# 4  07  RENTALS - WALKUP APARTMENTS                                2B    373
#
#     LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0    19                                  A4
# 1    24                                  C0
# 2    66                                  C0
# 3  1101                                  R6
# 4    16                                  C1
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  526 EAST 5TH STREET                                         ...
# 1  264 EAST 7TH STREET                                         ...
# 2  243 EAST 7TH   STREET                                       ...
# 3  238 EAST 4TH   STREET                         -             ...
# 4  326 EAST 4TH   STREET                                       ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 0            1              1883
# 1                  3                 0            3              2059
# 2                  3                 0            3              2381
# 3                  1                 0            1                 0
# 4                 10                 0           10              2204
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               5200        1900                          1
# 1               3696        1900                          1
# 2               3084        1899                          1
# 3                  0        1955                          1
# 4               8625        1899                          2
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              A4    6500000 2015-03-18
# 1                              C0    3775000 2015-10-22
# 2                              C0    2900000 2015-06-24
# 3                              R6    6995000 2015-06-15
# 4                              C1   20000000 2015-11-17
#
# [5 rows x 21 columns]

# %%
#checking null values by columns
df_2015.isnull().mean() * 100
# Out:
# BOROUGH                           0.0
# NEIGHBORHOOD                      0.0
# BUILDING CLASS CATEGORY           0.0
# TAX CLASS AT PRESENT              0.0
# BLOCK                             0.0
# LOT                               0.0
# EASE-MENT                         0.0
# BUILDING CLASS AT PRESENT         0.0
# ADDRESS                           0.0
# APARTMENT NUMBER                  0.0
# ZIP CODE                          0.0
# RESIDENTIAL UNITS                 0.0
# COMMERCIAL UNITS                  0.0
# TOTAL UNITS                       0.0
# LAND SQUARE FEET                  0.0
# GROSS SQUARE FEET                 0.0
# YEAR BUILT                        0.0
# TAX CLASS AT TIME OF SALE         0.0
# BUILDING CLASS AT TIME OF SALE    0.0
# SALE PRICE                        0.0
# SALE DATE                         0.0
# dtype: float64

# %% [markdown]
# **2016 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2016_*.xls')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [4]), all_files)
li_2 = list(li_mapper)
df_2016 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2016.columns = df_2010.columns
df_2016.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        2  BATHGATE
# 1        2  BATHGATE
# 2        2  BATHGATE
# 3        2  BATHGATE
# 4        2  BATHGATE
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY DWELLINGS                                        1   3037
# 1  01  ONE FAMILY DWELLINGS                                        1   3043
# 2  01  ONE FAMILY DWELLINGS                                        1   3046
# 3  01  ONE FAMILY DWELLINGS                                        1   3046
# 4  01  ONE FAMILY DWELLINGS                                        1   3048
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0  101                                  S0
# 1   55                                  A1
# 2   52                                  A1
# 3   52                                  A1
# 4   27                                  A1
#
#                                      ADDRESS APARTMENT NUMBER  ...  \
# 0  443 EAST 180 STREET                                         ...
# 1  1948 BATHGATE AVENUE                                        ...
# 2  2047 BATHGATE AVENUE                                        ...
# 3  2047 BATHGATE AVENUE                                        ...
# 4  538 EAST 182 STREET                                         ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 2            3              1293
# 1                  1                 0            1              2356
# 2                  1                 0            1              2329
# 3                  1                 0            1              2329
# 4                  1                 0            1              1209
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               2310        1952                          1
# 1               2047        1901                          1
# 2               1431        1901                          1
# 3               1431        1901                          1
# 4               1048        1901                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              S0          0 2016-08-06
# 1                              A1     220000 2016-06-22
# 2                              A1     273796 2016-09-21
# 3                              A1     231244 2016-09-21
# 4                              A1          0 2016-09-20
#
# [5 rows x 21 columns]

# %%
#checking null values by columns
df_2016.isnull().mean() * 100
# Out:
# BOROUGH                           0.0
# NEIGHBORHOOD                      0.0
# BUILDING CLASS CATEGORY           0.0
# TAX CLASS AT PRESENT              0.0
# BLOCK                             0.0
# LOT                               0.0
# EASE-MENT                         0.0
# BUILDING CLASS AT PRESENT         0.0
# ADDRESS                           0.0
# APARTMENT NUMBER                  0.0
# ZIP CODE                          0.0
# RESIDENTIAL UNITS                 0.0
# COMMERCIAL UNITS                  0.0
# TOTAL UNITS                       0.0
# LAND SQUARE FEET                  0.0
# GROSS SQUARE FEET                 0.0
# YEAR BUILT                        0.0
# TAX CLASS AT TIME OF SALE         0.0
# BUILDING CLASS AT TIME OF SALE    0.0
# SALE PRICE                        0.0
# SALE DATE                         0.0
# dtype: float64

# %% [markdown]
# **2017 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2017_*.xls')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [4]), all_files)
li_2 = list(li_mapper)
df_2017 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2017.columns = df_2010.columns
df_2017.head()
# Out:
#    BOROUGH NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 1        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 2        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 3        2     BATHGATE  01 ONE FAMILY DWELLINGS
# 4        2     BATHGATE  01 ONE FAMILY DWELLINGS
#
#   TAX CLASS AT PRESENT  BLOCK  LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                    1   3028   25                                  A5
# 1                    1   3030   55                                  A5
# 2                    1   3030   56                                  A1
# 3                    1   3030   56                                  A1
# 4                    1   3030   65                                  A1
#
#                  ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0    412 EAST 179 STREET                   ...                  1
# 1  410 EAST 182ND STREET                   ...                  1
# 2    412 EAST 182 STREET                   ...                  1
# 3    412 EAST 182 STREET                   ...                  1
# 4       4455 PARK AVENUE                   ...                  1
#
#    COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 0                 0            1              1842               2048
# 1                 0            1              1330               1460
# 2                 0            1              1306               1440
# 3                 0            1              1306               1440
# 4                 0            1              1622               1587
#
#    YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 0        1901                          1                              A5
# 1        1899                          1                              A5
# 2        1899                          1                              A1
# 3        1899                          1                              A1
# 4        1899                          1                              A1
#
#   SALE PRICE  SALE DATE
# 0          0 2017-04-04
# 1     305000 2017-07-18
# 2     178000 2017-01-19
# 3     449000 2017-07-14
# 4     140000 2017-05-12
#
# [5 rows x 21 columns]

# %%
#checking null values by columns
df_2017.isnull().mean() * 100
# Out:
# BOROUGH                           0.0
# NEIGHBORHOOD                      0.0
# BUILDING CLASS CATEGORY           0.0
# TAX CLASS AT PRESENT              0.0
# BLOCK                             0.0
# LOT                               0.0
# EASE-MENT                         0.0
# BUILDING CLASS AT PRESENT         0.0
# ADDRESS                           0.0
# APARTMENT NUMBER                  0.0
# ZIP CODE                          0.0
# RESIDENTIAL UNITS                 0.0
# COMMERCIAL UNITS                  0.0
# TOTAL UNITS                       0.0
# LAND SQUARE FEET                  0.0
# GROSS SQUARE FEET                 0.0
# YEAR BUILT                        0.0
# TAX CLASS AT TIME OF SALE         0.0
# BUILDING CLASS AT TIME OF SALE    0.0
# SALE PRICE                        0.0
# SALE DATE                         0.0
# dtype: float64

# %% [markdown]
# **2018 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2018_*.xlsx')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [4]), all_files)
li_2 = list(li_mapper)
df_2018 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2018.columns = df_2010.columns
df_2018.head()
# Out:
#    BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0        5     ANNADALE  01 ONE FAMILY DWELLINGS                    1   5391
# 1        5     ANNADALE  01 ONE FAMILY DWELLINGS                    1   5403
# 2        5     ANNADALE  01 ONE FAMILY DWELLINGS                    1   5404
# 3        5     ANNADALE  01 ONE FAMILY DWELLINGS                    1   5406
# 4        5     ANNADALE  01 ONE FAMILY DWELLINGS                    1   5408
#
#    LOT  EASE-MENT BUILDING CLASS AT PRESENT              ADDRESS  \
# 0   65        NaN                        A3  22 BLUE HERON DRIVE
# 1    8        NaN                        A1   254 SHIRLEY AVENUE
# 2   46        NaN                        A1    119 LENZIE STREET
# 3   26        NaN                        A2    87 ELMBANK STREET
# 4    7        NaN                        A2  192 BATHGATE STREET
#
#   APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# 0              NaN  ...                1.0               0.0          1.0
# 1              NaN  ...                1.0               0.0          1.0
# 2              NaN  ...                1.0               0.0          1.0
# 3              NaN  ...                1.0               0.0          1.0
# 4              NaN  ...                1.0               0.0          1.0
#
#    LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0            8000.0             3000.0      1987.0                          1
# 1            7500.0             3205.0      1970.0                          1
# 2            8000.0             3660.0      1998.0                          1
# 3            5000.0              912.0      1950.0                          1
# 4            2500.0              572.0      1930.0                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              A3    1185000 2018-03-19
# 1                              A1     915000 2018-12-21
# 2                              A1    1250000 2018-11-01
# 3                              A2     530000 2018-04-27
# 4                              A2     375000 2018-09-27
#
# [5 rows x 21 columns]

# %%
#checking null values by columns
df_2018.isnull().mean() * 100
# Out:
# BOROUGH                             0.000000
# NEIGHBORHOOD                        0.000000
# BUILDING CLASS CATEGORY             0.000000
# TAX CLASS AT PRESENT                0.063259
# BLOCK                               0.000000
# LOT                                 0.000000
# EASE-MENT                         100.000000
# BUILDING CLASS AT PRESENT           0.063259
# ADDRESS                             0.000000
# APARTMENT NUMBER                   78.006016
# ZIP CODE                            0.002387
# RESIDENTIAL UNITS                   0.063259
# COMMERCIAL UNITS                    0.063259
# TOTAL UNITS                         0.063259
# LAND SQUARE FEET                    0.064453
# GROSS SQUARE FEET                   0.063259
# YEAR BUILT                          0.003581
# TAX CLASS AT TIME OF SALE           0.000000
# BUILDING CLASS AT TIME OF SALE      0.000000
# SALE PRICE                          0.000000
# SALE DATE                           0.000000
# dtype: float64

# %% [markdown]
# **2019 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2019_*.xlsx')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [4]), all_files)
li_2 = list(li_mapper)
df_2019 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2019.columns = df_2010.columns
df_2019.head()
# Out:
#    BOROUGH   NEIGHBORHOOD    BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0        1  ALPHABET CITY    01 ONE FAMILY DWELLINGS                    1
# 1        1  ALPHABET CITY    01 ONE FAMILY DWELLINGS                    1
# 2        1  ALPHABET CITY    02 TWO FAMILY DWELLINGS                    1
# 3        1  ALPHABET CITY  03 THREE FAMILY DWELLINGS                    1
# 4        1  ALPHABET CITY  03 THREE FAMILY DWELLINGS                    1
#
#    BLOCK  LOT  EASE-MENT BUILDING CLASS AT PRESENT               ADDRESS  \
# 0    376   43        NaN                        S1   743 EAST 6TH STREET
# 1    390   61        NaN                        A4   189 EAST 7TH STREET
# 2    404    1        NaN                        B9          166 AVENUE A
# 3    377   56        NaN                        C0   263 EAST 7TH STREET
# 4    393    9        NaN                        C0  604 EAST 11TH STREET
#
#   APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# 0              NaN  ...                1.0               1.0          2.0
# 1              NaN  ...                1.0               0.0          1.0
# 2              NaN  ...                2.0               0.0          2.0
# 3              NaN  ...                3.0               0.0          3.0
# 4              NaN  ...                3.0               0.0          3.0
#
#    LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0            2090.0             3680.0      1940.0                          1
# 1             987.0             2183.0      1860.0                          1
# 2            1510.0             4520.0      1900.0                          1
# 3            2430.0             3600.0      1899.0                          1
# 4            2375.0             5110.0      1939.0                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                              S1    3200000 2019-07-24
# 1                              A4          0 2019-09-25
# 2                              B9          0 2019-07-22
# 3                              C0    6300000 2019-04-30
# 4                              C0          0 2019-10-24
#
# [5 rows x 21 columns]

# %%
#checking null values by columns
df_2019.isnull().mean() * 100
# Out:
# BOROUGH                             0.000000
# NEIGHBORHOOD                        0.000000
# BUILDING CLASS CATEGORY             0.000000
# TAX CLASS AT PRESENT                0.227598
# BLOCK                               0.000000
# LOT                                 0.000000
# EASE-MENT                         100.000000
# BUILDING CLASS AT PRESENT           0.227598
# ADDRESS                             0.000000
# APARTMENT NUMBER                   78.147045
# ZIP CODE                            0.016683
# RESIDENTIAL UNITS                  20.463537
# COMMERCIAL UNITS                   20.463537
# TOTAL UNITS                        20.463537
# LAND SQUARE FEET                   20.463537
# GROSS SQUARE FEET                  20.463537
# YEAR BUILT                          7.178265
# TAX CLASS AT TIME OF SALE           0.000000
# BUILDING CLASS AT TIME OF SALE      0.000000
# SALE PRICE                          0.000000
# SALE DATE                           0.000000
# dtype: float64

# %% [markdown]
# **2020 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2020_*.xlsx')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [6]), all_files)
li_2 = list(li_mapper)
df_2020 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2020.columns = df_2010.columns
df_2020.head()
# Out:
#    BOROUGH        NEIGHBORHOOD        BUILDING CLASS CATEGORY  \
# 0      NaN                 NaN                            NaN
# 1      4.0         AIRPORT JFK   39 TRANSPORTATION FACILITIES
# 2      4.0  AIRPORT LA GUARDIA        01 ONE FAMILY DWELLINGS
# 3      4.0  AIRPORT LA GUARDIA  12 CONDOS - WALKUP APARTMENTS
# 4      4.0             ARVERNE        01 ONE FAMILY DWELLINGS
#
#   TAX CLASS AT PRESENT    BLOCK     LOT  EASE-MENT BUILDING CLASS AT PRESENT  \
# 0                  NaN      NaN     NaN        NaN                       NaN
# 1                    4  14260.0    80.0        NaN                        V7
# 2                    1    949.0    41.0        NaN                        A5
# 3                    2    949.0  1003.0        NaN                        R2
# 4                    1  15830.0    20.0        NaN                        A5
#
#                 ADDRESS APARTMENT NUMBER  ...  RESIDENTIAL UNITS  \
# 0                   NaN              NaN  ...                NaN
# 1     N/A ROCKAWAY BLVD              NaN  ...                0.0
# 2     19-62 81ST STREET              NaN  ...                1.0
# 3  19-37 80TH STREET, 1                1  ...                1.0
# 4  3-20 BEACH 41 STREET              NaN  ...                1.0
#
#    COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 0               NaN          NaN               NaN                NaN
# 1               0.0          0.0          268092.0                0.0
# 2               0.0          1.0            1800.0             1224.0
# 3               0.0          1.0               0.0                0.0
# 4               0.0          1.0            2469.0             1476.0
#
#    YEAR BUILT  TAX CLASS AT TIME OF SALE  BUILDING CLASS AT TIME OF SALE  \
# 0         NaN                        NaN                             NaN
# 1         NaN                        4.0                              T1
# 2      1945.0                        1.0                              A5
# 3         NaN                        2.0                              R2
# 4      2005.0                        1.0                              A5
#
#   SALE PRICE  SALE DATE
# 0        NaN        NaT
# 1  4121000.0 2020-07-16
# 2   584569.0 2020-08-28
# 3   420000.0 2020-03-12
# 4   300000.0 2020-12-16
#
# [5 rows x 21 columns]

# %%
#checking null values by columns and deleting first null row
df_2020 = df_2020.iloc[1: , :]
df_2020.isnull().mean() * 100
# Out:
# BOROUGH                             0.005823
# NEIGHBORHOOD                        0.005823
# BUILDING CLASS CATEGORY             0.005823
# TAX CLASS AT PRESENT                0.064058
# BLOCK                               0.005823
# LOT                                 0.005823
# EASE-MENT                         100.000000
# BUILDING CLASS AT PRESENT           0.064058
# ADDRESS                             0.005823
# APARTMENT NUMBER                   78.073317
# ZIP CODE                            0.021838
# RESIDENTIAL UNITS                  18.750000
# COMMERCIAL UNITS                   18.750000
# TOTAL UNITS                        18.750000
# LAND SQUARE FEET                   18.750000
# GROSS SQUARE FEET                  18.750000
# YEAR BUILT                          7.062369
# TAX CLASS AT TIME OF SALE           0.005823
# BUILDING CLASS AT TIME OF SALE      0.005823
# SALE PRICE                          0.005823
# SALE DATE                           0.005823
# dtype: float64

# %% [markdown]
# **2021 Data**

# %%
#getting paths of folder from 2010 only
path = r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/'
all_files = glob.glob(path + '/2021_*.xlsx')

# %%
#mapping all files and merging in one place
li_mapper = map(lambda filename: pd.read_excel(filename, index_col = None, header = [6]), all_files)
li_2 = list(li_mapper)
df_2021 = pd.concat(li_2, axis = 0, ignore_index = True)
df_2021.columns = df_2010.columns
df_2021.head()
# Out:
#    BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY TAX CLASS AT PRESENT   BLOCK  \
# 0      NaN          NaN                      NaN                  NaN     NaN
# 1      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3028.0
# 2      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3028.0
# 3      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3039.0
# 4      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3045.0
#
#     LOT  EASE-MENT BUILDING CLASS AT PRESENT                ADDRESS  \
# 0   NaN        NaN                       NaN                    NaN
# 1  23.0        NaN                        A1  408 EAST 179TH STREET
# 2  24.0        NaN                        A1  410 EAST 179TH STREET
# 3  63.0        NaN                        A1  469 EAST 185TH STREET
# 4  12.0        NaN                        A1   2052 BATHGATE AVENUE
#
#   APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# 0              NaN  ...                NaN               NaN          NaN
# 1              NaN  ...                1.0               0.0          1.0
# 2              NaN  ...                1.0               0.0          1.0
# 3              NaN  ...                1.0               0.0          1.0
# 4              NaN  ...                1.0               0.0          1.0
#
#    LAND SQUARE FEET  GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               NaN                NaN         NaN                        NaN
# 1            1842.0             2048.0      1901.0                        1.0
# 2            1842.0             2048.0      1901.0                        1.0
# 3            1650.0             1296.0      1910.0                        1.0
# 4            2340.0             1516.0      1910.0                        1.0
#
#    BUILDING CLASS AT TIME OF SALE SALE PRICE  SALE DATE
# 0                             NaN        NaN        NaT
# 1                              A1        0.0 2021-01-20
# 2                              A1   600000.0 2021-01-15
# 3                              A1   455000.0 2021-12-23
# 4                              A1   580000.0 2021-07-22
#
# [5 rows x 21 columns]

# %%
#checking null values by columns and deleting first null row
df_2021 = df_2021.iloc[1: , :]
df_2021.isnull().mean() * 100
# Out:
# BOROUGH                             0.004037
# NEIGHBORHOOD                        0.004037
# BUILDING CLASS CATEGORY             0.004037
# TAX CLASS AT PRESENT                0.176600
# BLOCK                               0.004037
# LOT                                 0.004037
# EASE-MENT                         100.000000
# BUILDING CLASS AT PRESENT           0.176600
# ADDRESS                             0.004037
# APARTMENT NUMBER                   74.797667
# ZIP CODE                            0.005046
# RESIDENTIAL UNITS                  23.774396
# COMMERCIAL UNITS                   43.063152
# TOTAL UNITS                        20.693483
# LAND SQUARE FEET                   46.144065
# GROSS SQUARE FEET                  46.144065
# YEAR BUILT                          7.110420
# TAX CLASS AT TIME OF SALE           0.004037
# BUILDING CLASS AT TIME OF SALE      0.004037
# SALE PRICE                          0.004037
# SALE DATE                           0.004037
# dtype: float64

# %% [markdown]
# **Merging**
#
# Now with all the bases treated and merged annually we need to merge them into one dataset and perform some more cleanup

# %%
#merging all dataframes
merged_df = pd.concat([df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018,df_2019, df_2020, df_2021])

# %%
#cleaning
merged_df = merged_df.loc[(merged_df[['SALE PRICE']] != 0).all(axis=1)] #dropping sales prices = 0, it means home transfer
merged_df = merged_df[merged_df['ZIP CODE'].notna()] # dropping null zip codes
merged_df = merged_df.drop(['TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT', 'BUILDING CLASS AT PRESENT', 'ADDRESS','TAX CLASS AT TIME OF SALE','BUILDING CLASS AT TIME OF SALE','APARTMENT NUMBER'], axis=1) #drop not import for analysis columns
merged_df = merged_df.sort_values(by="SALE DATE") #sorting value by date
merged_df['ZIP CODE'] = merged_df['ZIP CODE'].astype(int) #converting zip code from float to int
merged_df['MONTH_YEAR'] = pd.to_datetime(merged_df['SALE DATE']).dt.to_period('M') #extracting month year from date to group
merged_df = merged_df.reset_index(drop=True) #reseting index

# %%
merged_df.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0      3.0  GREENPOINT
# 1      3.0  GREENPOINT
# 2      3.0  FLATBUSH-NORTH
# 3      3.0  WILLIAMSBURG-EAST
# 4      3.0  WILLIAMSBURG-EAST
#
#                         BUILDING CLASS CATEGORY  ZIP CODE  RESIDENTIAL UNITS  \
# 0  31  COMMERCIAL VACANT LAND                       11222                0.0
# 1  41  TAX CLASS 4 - OTHER                          11222                0.0
# 2  22  STORE BUILDINGS                              11203                0.0
# 3  02  TWO FAMILY HOMES                             11211                2.0
# 4  02  TWO FAMILY HOMES                             11211                2.0
#
#    COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# 0               0.0          0.0           18000.0                0.0
# 1               0.0          0.0            6000.0                0.0
# 2               3.0          3.0            4468.0             4075.0
# 3               0.0          2.0            1500.0             2142.0
# 4               0.0          2.0             880.0             1680.0
#
#    YEAR BUILT  SALE PRICE  SALE DATE MONTH_YEAR
# 0         0.0    990000.0 2010-01-01    2010-01
# 1         0.0    330000.0 2010-01-01    2010-01
# 2      1930.0    120959.0 2010-01-01    2010-01
# 3      1920.0        10.0 2010-01-01    2010-01
# 4      1920.0        10.0 2010-01-01    2010-01

# %% [markdown]
# ### Aggregating home sales data for monthly period

# %% [markdown]
# **Grouping Housing sales to Monthly Sale**

# %%
sales_group = merged_df.groupby(['MONTH_YEAR','ZIP CODE'])['SALE PRICE'].agg(Median_Sales = 'median', Sum_Sales ='sum', Std_Sales = 'std', Avg_sales = 'mean' ,Number_Sales = 'count')
sales_group = sales_group.add_suffix('_Group').reset_index() #creating tabular data

# %% [markdown]
# **Grouping Housing by Residential Units**

# %%
residential_group = merged_df.groupby(['MONTH_YEAR','ZIP CODE'])['RESIDENTIAL UNITS'].agg(Sum_Residential_Units ='sum')
residential_group = residential_group.add_suffix('_Group').reset_index() #creating tabular data

# %% [markdown]
# **Grouping Housing by Commercial Units**

# %%
commercial_group = merged_df.groupby(['MONTH_YEAR','ZIP CODE'])['COMMERCIAL UNITS'].agg(Sum_Commercial_Units ='sum')
commercial_group = commercial_group.add_suffix('_Group').reset_index() #creating tabular data

# %% [markdown]
# **Grouping by Land Squarte Feet**

# %%
land_group = merged_df.groupby(['MONTH_YEAR','ZIP CODE'])['LAND SQUARE FEET'].agg(Avg_land_square = 'mean', Sum_land_square ='sum')
land_group = land_group.add_suffix('_Group').reset_index() #creating tabular data

# %% [markdown]
# **Grouping by Gross Square Feet**

# %%
gross_land_group = merged_df.groupby(['MONTH_YEAR','ZIP CODE'])['GROSS SQUARE FEET'].agg(Avg_gross_land_square = 'mean', Sum_gross_land_square ='sum')
gross_land_group = gross_land_group.add_suffix('_Group').reset_index() #creating tabular data

# %% [markdown]
# ### Extracting postal codes by region name

# %% [markdown]
# **Using external Neighborhood by zip code Data source**: https://github.com/erikgregorywebb/nyc-housing/blob/master/Data/nyc-zip-codes.csv

# %%
url_z = "https://raw.githubusercontent.com/erikgregorywebb/nyc-housing/master/Data/nyc-zip-codes.csv"
df_zips =pd.read_csv(url_z, sep=',', header = [0])
df_zips = df_zips.rename(columns={"ZipCode": "Zip_code"})
df_zips.head()
# Out:
#   Borough            Neighborhood  Zip_code
# 0   Bronx           Central Bronx     10453
# 1   Bronx           Central Bronx     10457
# 2   Bronx           Central Bronx     10460
# 3   Bronx  Bronx Park and Fordham     10458
# 4   Bronx  Bronx Park and Fordham     10467

# %% [markdown]
# **Creating Monthly Dataframe with ZIP renames**

# %%
from functools import reduce
dfs = [sales_group,residential_group,commercial_group,land_group,gross_land_group]
df_houses = reduce(lambda left,right: pd.merge(left,right,on=['MONTH_YEAR', 'ZIP CODE']), dfs)

# %%
df_houses.columns
# Out:
# Index(['MONTH_YEAR', 'ZIP CODE', 'Median_Sales_Group', 'Sum_Sales_Group',
#        'Std_Sales_Group', 'Avg_sales_Group', 'Number_Sales_Group',
#        'Sum_Residential_Units_Group', 'Sum_Commercial_Units_Group',
#        'Avg_land_square_Group', 'Sum_land_square_Group',
#        'Avg_gross_land_square_Group', 'Sum_gross_land_square_Group'],
#       dtype='object')

# %%
#renaming columns
dict = {'MONTH_YEAR': 'Month_Year',
        'ZIP CODE': 'Zip_code',
        'Median_Sales_Group': 'Median_Sales',
       'Sum_Sales_Group':'Sum_Sales',
       'Std_Sales_Group':'Std_Sales',
        'Avg_sales_Group' : 'Avg_Sales',
       'Number_Sales_Group':'Amount_Sales',
       'Sum_Residential_Units_Group':'Sum_Residential_Units',
       'Sum_Commercial_Units_Group':'Sum_Commercial_Units',
       'Avg_land_square_Group':'Avg_Land_sqft',
       'Avg_gross_land_square_group':'Avg_gross_sqft'}
 
# call rename () method
df_houses.rename(columns=dict,
          inplace=True)

# %%
#aggregating neighbourhoods and boroughs
df_houses = pd.merge(df_houses, df_zips, on=['Zip_code'], how='left')

# %%
df_houses.head()
# Out:
#   Month_Year  Zip_code  Median_Sales    Sum_Sales     Std_Sales     Avg_Sales  \
# 0    2010-01         0      962246.0    1924492.0  7.199761e+03  9.622460e+05
# 1    2010-01     10001      635500.0    5433127.0  5.449819e+05  7.761610e+05
# 2    2010-01     10002      480860.0    7837470.0  2.932861e+05  5.598193e+05
# 3    2010-01     10003      767358.0  189117679.0  2.114628e+07  4.727942e+06
# 4    2010-01     10004      845147.0  113640540.0  3.539178e+07  1.262673e+07
#
#    Amount_Sales  Sum_Residential_Units  Sum_Commercial_Units  Avg_Land_sqft  \
# 0             2                    4.0                   0.0    3825.000000
# 1             7                  295.0                   3.0    2239.571429
# 2            14                    4.0                   0.0       0.000000
# 3            40                  264.0                   2.0     564.500000
# 4             9                    6.0                   1.0    6002.555556
#
#    Sum_land_square_Group  Avg_gross_land_square_Group  \
# 0                 7650.0                  3621.500000
# 1                15677.0                 38563.857143
# 2                    0.0                     0.000000
# 3                22580.0                  4918.050000
# 4                54023.0                112934.000000
#
#    Sum_gross_land_square_Group    Borough         Neighborhood
# 0                       7243.0        NaN                  NaN
# 1                     269947.0  Manhattan  Chelsea and Clinton
# 2                          0.0  Manhattan      Lower East Side
# 3                     196722.0  Manhattan      Lower East Side
# 4                    1016406.0  Manhattan      Lower Manhattan

# %% [markdown]
# ## **NYC 311 Service Requests** <a class="anchor" id="section_1_2"></a>

# %% [markdown]
# The database available by the city of new york, is extremely massive, from 2010 to 2022 there were more than **24 million requests** by city residents to request some municipal service, additionally the **csv file has 16gb** creating a challenge for treatment via pandas, so we looked for external software to help us in this task. To perform an initial cleaning just for water related requests, we used the Alteryx software that deals well with big data and distributed computing, below you can see the flow we did to extract the following complaints:

# %%
#loading dataset
comp = pd.read_csv('nyc_water_2.csv')

# %%
#list of complaints releated to water
types_complaints = list(comp['Complaint Type'].unique())
types_complaints
# Out:
# ['Air Quality',
#  'Dirty Conditions',
#  'General Construction/Plumbing',
#  'Hazardous Materials',
#  'Indoor Air Quality',
#  'Industrial Waste',
#  'Plumbing',
#  'Rodent',
#  'Root/Sewer/Sidewalk Condition',
#  'Sewer',
#  'Water Quality',
#  'Water System',
#  'Asbestos',
#  'Beach/Pool/Sauna Complaint',
#  'Drinking Water',
#  'Indoor Sewage',
#  'Unsanitary Condition',
#  'Asbestos/Garbage Nuisance',
#  'Mosquitoes',
#  'Illegal Dumping',
#  'Dumpster Complaint']

# %% [markdown]
# ![flow](flow.png)

# %%
#cleaning 
comp = comp[(comp['Date'] <= '2021-12-31')] #filtering to match dates of house sales
comp = comp[comp['Incident Zip'].notna()] # dropping null zip codes
comp['Incident Zip'] = comp['Incident Zip'].astype(int) #converting zip code from float to int
zip_codes = merged_df['ZIP CODE'].unique() #creating list of zip codes from sales house to match complaints df
comp = comp[comp['Incident Zip'].isin(zip_codes)] #filtering df to match zip codes
comp["Complaint Type"]= comp["Complaint Type"].str.title() #transforming complaint type to title to lower the variations
comp['Date_month'] = pd.to_datetime(comp['Date']).dt.to_period('M') #exctracting data month from date for grouping

# %%
comp.head()
# Out:
#          Date  Average 24hrTurbidity(NTU)  Coliform, Fecal(fc/100mL) Agency  \
# 0  2010-01-01                         NaN                        NaN    DEP
# 1  2010-01-01                         NaN                        NaN    DEP
# 2  2010-01-01                         NaN                        NaN    DEP
# 3  2010-01-01                         NaN                        NaN    DEP
# 4  2010-01-01                         NaN                        NaN    DEP
#
#                               Agency Name Complaint Type          City  \
# 0  Department of Environmental Protection    Air Quality      Brooklyn
# 1  Department of Environmental Protection    Air Quality  Forest Hills
# 2  Department of Environmental Protection    Air Quality      New York
# 3  Department of Environmental Protection    Air Quality      New York
# 4  Department of Environmental Protection    Air Quality      Brooklyn
#
#      Borough   Latitude  Longitude  Incident Zip Date_month
# 0   Brooklyn  40.642356 -73.885252         11236    2010-01
# 1     Queens  40.719680 -73.845930         11375    2010-01
# 2  Manhattan  40.773144 -73.948562         10028    2010-01
# 3  Manhattan  40.706283 -74.017904         10280    2010-01
# 4   Brooklyn  40.643772 -73.999031         11220    2010-01

# %% [markdown]
# **Grouping to monthly data in order to append in sales dataset**

# %%
g1 = comp.groupby( [ "Date_month", "Incident Zip", 'Complaint Type'] ).count() #grouping amount of complaints
g1 = g1.add_suffix('_Count').reset_index() #creating tabular data
g1 = g1.drop(g1.columns[[4, 5,6,7,8,9,10,11]], axis=1) #dropping unecessary columns
g1 = g1.rename(columns={"Date_Count": "Amount of Complaints", 'Date_month': 'Month_Year', 'Incident Zip':'Zip_code'}, errors="raise") #renaming column
g1 = g1.loc[(g1[['Amount of Complaints']] != 0).all(axis=1)] #filtering 0 values
g1 = g1.reset_index(drop=True) #reseting index
g1
# Out:
#        Month_Year  Zip_code                 Complaint Type  \
# 0         2010-01     10001                    Air Quality
# 1         2010-01     10001                       Asbestos
# 2         2010-01     10001               Dirty Conditions
# 3         2010-01     10001  General Construction/Plumbing
# 4         2010-01     10001            Hazardous Materials
# ...           ...       ...                            ...
# 274448    2021-12     11694                         Rodent
# 274449    2021-12     11694                          Sewer
# 274450    2021-12     11694           Unsanitary Condition
# 274451    2021-12     11694                   Water System
# 274452    2021-12     11697                Illegal Dumping
#
#         Amount of Complaints
# 0                          6
# 1                          2
# 2                          5
# 3                         25
# 4                          1
# ...                      ...
# 274448                     1
# 274449                     4
# 274450                     8
# 274451                     4
# 274452                     1
#
# [274453 rows x 4 columns]

# %% [markdown]
# ## NYC Quality of Drinking Water data  <a class="anchor" id="section_1_3"></a>

# %% [markdown]
# To understand the total scenario of the city of new york in its environmental problems related to water, we searched for another dataset that has measures of the quality of drinking water in different regions of the city, this basis becomes challenging because the locations of collections are not revealed, however we found another dataset support informing EPSG coordinates can thus extract the latitude and longitude by an API doing the reverse geocode method
#
# Database Source:
# Drinking Water Quality Distribution Monitoring Data https://data.cityofnewyork.us/Environment/Drinking-Water-Quality-Distribution-Monitoring-Dat/bkwf-xfky

# %%
water_d = pd.read_csv('Drinking_Water_Quality_Distribution_Monitoring_Data.csv')
# Out:
# /Users/ale_muchinski/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
water_d.head()
# Out:
#    Sample Number Sample Date Sample Time Sample Site Sample class  \
# 0      201500023  01/01/2015       12:19        1S07  Operational
# 1      201500024  01/01/2015       11:15        1S04  Operational
# 2      201500025  01/01/2015       10:09       1S03A  Operational
# 3      201500026  01/01/2015       10:41       1S03B  Operational
# 4      201500027  01/01/2015       09:38       11550   Compliance
#
#    Residual Free Chlorine (mg/L) Turbidity (NTU) Fluoride (mg/L)  \
# 0                           0.58            0.96            0.79
# 1                           0.71            0.94            0.80
# 2                           0.79            0.93            0.79
# 3                           0.77            0.93            0.80
# 4                           0.74            0.95             NaN
#
#   Coliform (Quanti-Tray) (MPN /100mL) E.coli(Quanti-Tray) (MPN/100mL)
# 0                                  <1                              <1
# 1                                  <1                              <1
# 2                                  <1                              <1
# 3                                  <1                              <1
# 4                                  <1                              <1

# %% [markdown]
# **Drinkible Water Locations Sample Site Colletions**
#
# The new york government provides a dataset informing the location of each water collection and measurement location, the challenge is that we have to convert EPSG coordinates to latitude and longitude
#
# Database source: https://data.cityofnewyork.us/api/views/bkwf-xfky/files/e93e4856-95f7-48d4-b4c0-fa54989cdbfc?download=true&filename=OpenData_Distribution_Water_Quality_Sampling_Sites_Updated_2021-0618.xlsx

# %%
water_sites = pd.read_excel('OpenData_Distribution_Water_Quality_Sampling_Sites_Updated_2021-0618.xlsx')
water_sites.head()
# Out:
#   Sample Site         Sample Station (SS) - Location Description  \
# 0        1S03  SS - Shaft 3 of City Tunnel No.1 - E/S Goulden...
# 1        1S04  SS - Shaft 4 of City Tunnel No.1 - IFO 2780 Re...
# 2       1S03A  SS - Shaft 3A of City Tunnel No.2 - S/S E 233r...
# 3        1S07  SS - Shaft 7 of City Tunnel No.1 - NE/S W 167t...
# 4       1S03B  SS - Shaft 3B of City Tunnel No.3 - W/S Jerome...
#
#    X - Coordinate  Y - Coordinate
# 0         1024950          264277
# 1         1012568          256577
# 2         1024721          264392
# 3         1004013          245233
# 4         1014949          260688

# %%
#installin^g package to convert state coordinates to latitude and longitude
# !pip install pyproj
# Out:
# Requirement already satisfied: pyproj in /Users/ale_muchinski/opt/anaconda3/lib/python3.9/site-packages (3.3.1)
# Requirement already satisfied: certifi in /Users/ale_muchinski/opt/anaconda3/lib/python3.9/site-packages (from pyproj) (2021.10.8)

# %%
from pyproj import Transformer 

#transformer to convert from (epsg 3602 NAD83(NSRS2007) / Missouri East) to 4326 (WGS84 - World Geodetic System 1984, used in GPS)

transformer = Transformer.from_crs( "epsg:2263","epsg:4326",always_xy=False)

#empty lists to hold converted x y coordinates
lat = []
lon = []

#loop through columns 'XCoord' and 'YCoord' and declare variables x and y to use in transformer. 
#note I had to change the column values from feet to meters for the transformer to correctly work
for index, row in water_sites.iterrows():
    x = (row['X - Coordinate'])
    y = (row['Y - Coordinate'])
    
    #call transformer
    x1, y1 = transformer.transform(x,y)
      
    #append to lists    
    lat.append(x1)
    lon.append(y1)
    
# add new columns to df     
water_sites['Lat'] = lat
water_sites['Lon'] = lon

# %%
#checking if the conversion worked
import folium

tree_map = folium.Map(location=[water_sites.Lat.mean(), water_sites.Lon.mean()], zoom_start=10)
for index, tree_info  in water_sites.iterrows():

    folium.Marker([tree_info['Lat'], tree_info['Lon']]).add_to(tree_map)

tree_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ce08da1b8ce14ec482367f9c52e2d88d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ce08da1b8ce14ec482367f9c52e2d88d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ce08da1b8ce14ec482367f9c52e2d88d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ce08da1b8ce14ec482367f9c52e2d88d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.724928289824426%2C%20-73.93246531318259%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# **Reverse Geocode to get ZIP Codes**

# %%
import geopy
import pandas as pd
from geopy.extra.rate_limiter import RateLimiter


def get_zipcode(water_sites, geolocator, Lat, Lon):
    location = geolocator.reverse((water_sites[Lat], water_sites[Lon]))

    return location.raw['address']['postcode']

geolocator = geopy.Nominatim(user_agent='https://www.dtu.dk/')
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
zipcodes = water_sites.apply(get_zipcode, axis=1, geolocator=geolocator, Lat='Lat', Lon='Lon')

# %%
water_sites['Zip_code'] = zipcodes

# %%
water_sites.head()
# Out:
#   Sample Site         Sample Station (SS) - Location Description  \
# 0        1S03  SS - Shaft 3 of City Tunnel No.1 - E/S Goulden...
# 1        1S04  SS - Shaft 4 of City Tunnel No.1 - IFO 2780 Re...
# 2       1S03A  SS - Shaft 3A of City Tunnel No.2 - S/S E 233r...
# 3        1S07  SS - Shaft 7 of City Tunnel No.1 - NE/S W 167t...
# 4       1S03B  SS - Shaft 3B of City Tunnel No.3 - W/S Jerome...
#
#    X - Coordinate  Y - Coordinate        Lat        Lon Zip_code
# 0         1024950          264277  40.891959 -73.852793    10466
# 1         1012568          256577  40.870874 -73.897610    10468
# 2         1024721          264392  40.892276 -73.853621    10466
# 3         1004013          245233  40.839761 -73.928576    10452
# 4         1014949          260688  40.882149 -73.888982    10468

# %% [markdown]
# ### Merging Sample Sites with ZIP codes to water quality datase

# %%
water_final = pd.merge(water_d, water_sites, on=['Sample Site'], how='left') #merging
water_final["Zip_code"] = water_final["Zip_code"].replace({"10002-1013": "10002", '10307:10312':'10307', '10454-4606':'10454'}) #cleaning weird ZIP codes from the API

water_final = water_final.drop(columns=['Sample Number','Sample Time','Sample Station (SS) - Location Description','X - Coordinate', 'Y - Coordinate'])#excluding not used columns
water_final['Sample Date'] = pd.to_datetime(water_final['Sample Date']) #converting date to datetime
water_final['MONTH_YEAR'] = pd.to_datetime(water_final['Sample Date']).dt.to_period('M')

# %%
#removing special characthers
water_final["Turbidity (NTU)"] = water_final['Turbidity (NTU)'].str.replace('<', '')
water_final["Fluoride (mg/L)"] = water_final['Fluoride (mg/L)'].str.replace('<', '')

# %%
#converting columns to float
water_final["Residual Free Chlorine (mg/L)"] = pd.to_numeric(water_final["Residual Free Chlorine (mg/L)"])
water_final["Turbidity (NTU)"] = pd.to_numeric(water_final["Turbidity (NTU)"])
water_final["Fluoride (mg/L)"] = pd.to_numeric(water_final["Fluoride (mg/L)"])

# %%
water_final
# Out:
#        Sample Date Sample Site Sample class  Residual Free Chlorine (mg/L)  \
# 0       2015-01-01        1S07  Operational                           0.58
# 1       2015-01-01        1S04  Operational                           0.71
# 2       2015-01-01       1S03A  Operational                           0.79
# 3       2015-01-01       1S03B  Operational                           0.77
# 4       2015-01-01       11550   Compliance                           0.74
# ...            ...         ...          ...                            ...
# 112456  2022-03-31       24550   Compliance                           0.35
# 112457  2022-03-31       27450   Compliance                           0.33
# 112458  2022-03-31       20900  Operational                           0.36
# 112459  2022-03-31       27000  Operational                           0.40
# 112460  2022-03-31       20950   Compliance                           0.32
#
#         Turbidity (NTU)  Fluoride (mg/L) Coliform (Quanti-Tray) (MPN /100mL)  \
# 0                  0.96             0.79                                  <1
# 1                  0.94             0.80                                  <1
# 2                  0.93             0.79                                  <1
# 3                  0.93             0.80                                  <1
# 4                  0.95              NaN                                  <1
# ...                 ...              ...                                 ...
# 112456             0.85              NaN                                  <1
# 112457             0.87              NaN                                  <1
# 112458             0.86              NaN                                  <1
# 112459             0.88              NaN                                  <1
# 112460             0.77              NaN                                  <1
#
#        E.coli(Quanti-Tray) (MPN/100mL)        Lat        Lon Zip_code  \
# 0                                   <1  40.839761 -73.928576    10452
# 1                                   <1  40.870874 -73.897610    10468
# 2                                   <1  40.892276 -73.853621    10466
# 3                                   <1  40.882149 -73.888982    10468
# 4                                   <1  40.874286 -73.857020    10469
# ...                                ...        ...        ...      ...
# 112456                              <1  40.634766 -73.936520    11210
# 112457                              <1  40.615182 -73.954256    11210
# 112458                              <1  40.699701 -73.983443    11201
# 112459                              <1  40.708104 -73.954553    11211
# 112460                              <1  40.695497 -73.991785    11201
#
#        MONTH_YEAR
# 0         2015-01
# 1         2015-01
# 2         2015-01
# 3         2015-01
# 4         2015-01
# ...           ...
# 112456    2022-03
# 112457    2022-03
# 112458    2022-03
# 112459    2022-03
# 112460    2022-03
#
# [112461 rows x 12 columns]

# %%
#Converting <1 to 0 since it's the smallest amount, also cleaning special charachaters and converting to float
water_final["Coliform (Quanti-Tray) (MPN /100mL)"] = water_final["Coliform (Quanti-Tray) (MPN /100mL)"].replace({"<1": "0"})
water_final["Coliform (Quanti-Tray) (MPN /100mL)"] = water_final['Coliform (Quanti-Tray) (MPN /100mL)'].str.replace('\W', '')
water_final["Coliform (Quanti-Tray) (MPN /100mL)"] = pd.to_numeric(water_final["Coliform (Quanti-Tray) (MPN /100mL)"])

#Converting <1 to 0 since it's the smallest amount, also cleaning special charachaters and converting to float
water_final["E.coli(Quanti-Tray) (MPN/100mL)"] = water_final["E.coli(Quanti-Tray) (MPN/100mL)"].replace({"<1": "0"})
water_final["E.coli(Quanti-Tray) (MPN/100mL)"] = water_final['E.coli(Quanti-Tray) (MPN/100mL)'].str.replace('\W', '')
water_final["E.coli(Quanti-Tray) (MPN/100mL)"] = pd.to_numeric(water_final["E.coli(Quanti-Tray) (MPN/100mL)"])
# Out:
# /var/folders/g_/cyhpn47s7m1_y4rg035gybmr0000gn/T/ipykernel_28430/3079924513.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   water_final["Coliform (Quanti-Tray) (MPN /100mL)"] = water_final['Coliform (Quanti-Tray) (MPN /100mL)'].str.replace('\W', '')
# /var/folders/g_/cyhpn47s7m1_y4rg035gybmr0000gn/T/ipykernel_28430/3079924513.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   water_final["E.coli(Quanti-Tray) (MPN/100mL)"] = water_final['E.coli(Quanti-Tray) (MPN/100mL)'].str.replace('\W', '')

# %%
water_final
# Out:
#        Sample Date Sample Site Sample class  Residual Free Chlorine (mg/L)  \
# 0       2015-01-01        1S07  Operational                           0.58
# 1       2015-01-01        1S04  Operational                           0.71
# 2       2015-01-01       1S03A  Operational                           0.79
# 3       2015-01-01       1S03B  Operational                           0.77
# 4       2015-01-01       11550   Compliance                           0.74
# ...            ...         ...          ...                            ...
# 112456  2022-03-31       24550   Compliance                           0.35
# 112457  2022-03-31       27450   Compliance                           0.33
# 112458  2022-03-31       20900  Operational                           0.36
# 112459  2022-03-31       27000  Operational                           0.40
# 112460  2022-03-31       20950   Compliance                           0.32
#
#         Turbidity (NTU)  Fluoride (mg/L)  Coliform (Quanti-Tray) (MPN /100mL)  \
# 0                  0.96             0.79                                  0.0
# 1                  0.94             0.80                                  0.0
# 2                  0.93             0.79                                  0.0
# 3                  0.93             0.80                                  0.0
# 4                  0.95              NaN                                  0.0
# ...                 ...              ...                                  ...
# 112456             0.85              NaN                                  0.0
# 112457             0.87              NaN                                  0.0
# 112458             0.86              NaN                                  0.0
# 112459             0.88              NaN                                  0.0
# 112460             0.77              NaN                                  0.0
#
#         E.coli(Quanti-Tray) (MPN/100mL)        Lat        Lon Zip_code  \
# 0                                   0.0  40.839761 -73.928576    10452
# 1                                   0.0  40.870874 -73.897610    10468
# 2                                   0.0  40.892276 -73.853621    10466
# 3                                   0.0  40.882149 -73.888982    10468
# 4                                   0.0  40.874286 -73.857020    10469
# ...                                 ...        ...        ...      ...
# 112456                              0.0  40.634766 -73.936520    11210
# 112457                              0.0  40.615182 -73.954256    11210
# 112458                              0.0  40.699701 -73.983443    11201
# 112459                              0.0  40.708104 -73.954553    11211
# 112460                              0.0  40.695497 -73.991785    11201
#
#        MONTH_YEAR
# 0         2015-01
# 1         2015-01
# 2         2015-01
# 3         2015-01
# 4         2015-01
# ...           ...
# 112456    2022-03
# 112457    2022-03
# 112458    2022-03
# 112459    2022-03
# 112460    2022-03
#
# [112461 rows x 12 columns]

# %% [markdown]
# ### Converting Water Quality Data to Monthly

# %% [markdown]
# **Grouping Monhthly by sample site and chlorine**

# %%
water_Residual = water_final.groupby(['MONTH_YEAR','Zip_code'])['Residual Free Chlorine (mg/L)'].agg(Avg_Residual_Free_Chlorine ='mean', Std_Residual_Free_Chlorine = 'std', Sum_of_Residual_Collections = 'count')
water_Residual = water_Residual.add_suffix('_Group').reset_index() #creating tabular data

# %% [markdown]
# **Grouping Monhthly by sample site and turbidity**

# %%
water_Turbidity = water_final.groupby(['MONTH_YEAR','Zip_code'])['Turbidity (NTU)'].agg(Avg_Turbidity ='mean', Std_Turbidity = 'std',Sum_of_Turbidity_Collections = 'count')
water_Turbidity = water_Turbidity.add_suffix('_Group').reset_index() #creating tabular data

# %% [markdown]
# **Grouping Monthly by sample site and Fluoride (mg/L)**

# %%
water_Flouride = water_final.groupby(['MONTH_YEAR','Zip_code'])['Fluoride (mg/L)'].agg(Avg_Fluoride ='mean', Std_Fluoride = 'std',Sum_of_Fluoride_Collections = 'count')
water_Flouride = water_Flouride.add_suffix('_Group').reset_index() #creating tabular data

# %% [markdown]
# **Grouping Monthly by sample site and Coliform**

# %%
water_Coliform = water_final.groupby(['MONTH_YEAR','Zip_code'])['Coliform (Quanti-Tray) (MPN /100mL)'].agg(Avg_Coliform ='mean', Std_Coliform = 'std',Sum_of_Coliform_Collections = 'count')
water_Coliform = water_Coliform.add_suffix('_Group').reset_index() #creating tabular data

# %% [markdown]
# **Merging all groupbys of water quality**

# %%
from functools import reduce
dfs_water = [water_Residual,water_Turbidity,water_Flouride,water_Coliform]
df_water_m = reduce(lambda left,right: pd.merge(left,right,on=['MONTH_YEAR', 'Zip_code']), dfs_water)
df_water_m['Zip_code'] = df_water_m['Zip_code'].astype('int') #converting zip code from object to int

# %%
#renaming columns
dict = {'MONTH_YEAR': 'Month_Year',
        'Zip_code': 'Zip_code',
        'Avg_Residual_Free_Chlorine_Group': 'Avg_Residual_Free_Chlorine',
       'Std_Residual_Free_Chlorine_Group':'Std_Residual_Free_Chlorine',
       'Sum_of_Residual_Collections_Group':'Count_of_Residual_Collections_Group',
        'Avg_Turbidity_Group' : 'Avg_Turbidity',
       'Std_Turbidity_Group':'Std_Turbidity',
       'Sum_of_Turbidity_Collections_Group':'Count_of_Turbidity_Collections',
       'Avg_Fluoride_Group':'Avg_Fluoride',
       'Std_Fluoride_Group':'Std_Fluoride',
       'Sum_of_Fluoride_Collections_Group':'Count_of_Fluoride_Collections',
       'Avg_Coliform_Group':'Avg_Coliform',
       'Std_Coliform_Group':'Std_Coliform',
       'Sum_of_Coliform_Collections_Group':'Count_of_Coliform_Collections'}
 
# call rename () method
df_water_m.rename(columns=dict,
          inplace=True)

# %%
#aggregating neighbourhoods and boroughs
df_water_final = pd.merge(df_houses, df_water_m, on=['Month_Year','Zip_code'], how='left')

# %%
df_water_final
# Out:
#       Month_Year  Zip_code  Median_Sales    Sum_Sales     Std_Sales  \
# 0        2010-01         0      962246.0    1924492.0  7.199761e+03
# 1        2010-01     10001      635500.0    5433127.0  5.449819e+05
# 2        2010-01     10002      480860.0    7837470.0  2.932861e+05
# 3        2010-01     10003      767358.0  189117679.0  2.114628e+07
# 4        2010-01     10004      845147.0  113640540.0  3.539178e+07
# ...          ...       ...           ...          ...           ...
# 25900    2021-12     11691      530000.0   17466976.0  2.356276e+05
# 25901    2021-12     11692      579500.0    4524000.0  2.690443e+05
# 25902    2021-12     11693      392000.0    7131800.0  2.070483e+05
# 25903    2021-12     11694      807000.0   15936313.0  5.043907e+05
# 25904    2021-12     11697      735000.0    6720000.0  3.091824e+05
#
#           Avg_Sales  Amount_Sales  Sum_Residential_Units  \
# 0      9.622460e+05             2                    4.0
# 1      7.761610e+05             7                  295.0
# 2      5.598193e+05            14                    4.0
# 3      4.727942e+06            40                  264.0
# 4      1.262673e+07             9                    6.0
# ...             ...           ...                    ...
# 25900  5.458430e+05            32                   56.0
# 25901  5.655000e+05             8                   13.0
# 25902  4.754533e+05            15                   15.0
# 25903  8.387533e+05            19                   31.0
# 25904  7.466667e+05             9                    0.0
#
#        Sum_Commercial_Units  Avg_Land_sqft  ...  \
# 0                       0.0    3825.000000  ...
# 1                       3.0    2239.571429  ...
# 2                       0.0       0.000000  ...
# 3                       2.0     564.500000  ...
# 4                       1.0    6002.555556  ...
# ...                     ...            ...  ...
# 25900                   0.0    6157.241379  ...
# 25901                   0.0    3472.571429  ...
# 25902                   2.0    3660.272727  ...
# 25903                   1.0    4282.909091  ...
# 25904                   0.0            NaN  ...
#
#        Count_of_Residual_Collections_Group  Avg_Turbidity  Std_Turbidity  \
# 0                                      NaN            NaN            NaN
# 1                                      NaN            NaN            NaN
# 2                                      NaN            NaN            NaN
# 3                                      NaN            NaN            NaN
# 4                                      NaN            NaN            NaN
# ...                                    ...            ...            ...
# 25900                                  4.0       0.625000       0.076811
# 25901                                  2.0       0.560000       0.042426
# 25902                                  5.0       0.620000       0.040620
# 25903                                  6.0       0.621667       0.049160
# 25904                                  3.0       0.583333       0.100167
#
#       Count_of_Turbidity_Collections Avg_Fluoride  Std_Fluoride  \
# 0                                NaN          NaN           NaN
# 1                                NaN          NaN           NaN
# 2                                NaN          NaN           NaN
# 3                                NaN          NaN           NaN
# 4                                NaN          NaN           NaN
# ...                              ...          ...           ...
# 25900                            4.0          NaN           NaN
# 25901                            2.0          NaN           NaN
# 25902                            5.0          NaN           NaN
# 25903                            6.0          NaN           NaN
# 25904                            3.0          NaN           NaN
#
#        Count_of_Fluoride_Collections  Avg_Coliform  Std_Coliform  \
# 0                                NaN           NaN           NaN
# 1                                NaN           NaN           NaN
# 2                                NaN           NaN           NaN
# 3                                NaN           NaN           NaN
# 4                                NaN           NaN           NaN
# ...                              ...           ...           ...
# 25900                            0.0           0.0           0.0
# 25901                            0.0           0.0           0.0
# 25902                            0.0           0.0           0.0
# 25903                            0.0           0.0           0.0
# 25904                            0.0           0.0           0.0
#
#        Count_of_Coliform_Collections
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 25900                            4.0
# 25901                            2.0
# 25902                            5.0
# 25903                            6.0
# 25904                            3.0
#
# [25905 rows x 27 columns]

# %% [markdown]
# ## NYC Merging all Dataframes <a class="anchor" id="section_1_4"></a>

# %% [markdown]
# After many transformations we arrive at the final database where we can see on a monthly level in 10 years the amount of complaints, value of real estate sales and water quality per zip code

# %%
df_final = pd.merge(df_water_final, g1, on=['Month_Year', 'Zip_code'], how='left')

# %%
df_final
# Out:
#        Month_Year  Zip_code  Median_Sales   Sum_Sales      Std_Sales  \
# 0         2010-01         0      962246.0   1924492.0    7199.761246
# 1         2010-01     10001      635500.0   5433127.0  544981.863818
# 2         2010-01     10001      635500.0   5433127.0  544981.863818
# 3         2010-01     10001      635500.0   5433127.0  544981.863818
# 4         2010-01     10001      635500.0   5433127.0  544981.863818
# ...           ...       ...           ...         ...            ...
# 272838    2021-12     11694      807000.0  15936313.0  504390.656181
# 272839    2021-12     11694      807000.0  15936313.0  504390.656181
# 272840    2021-12     11694      807000.0  15936313.0  504390.656181
# 272841    2021-12     11694      807000.0  15936313.0  504390.656181
# 272842    2021-12     11697      735000.0   6720000.0  309182.389537
#
#             Avg_Sales  Amount_Sales  Sum_Residential_Units  \
# 0       962246.000000             2                    4.0
# 1       776161.000000             7                  295.0
# 2       776161.000000             7                  295.0
# 3       776161.000000             7                  295.0
# 4       776161.000000             7                  295.0
# ...               ...           ...                    ...
# 272838  838753.315789            19                   31.0
# 272839  838753.315789            19                   31.0
# 272840  838753.315789            19                   31.0
# 272841  838753.315789            19                   31.0
# 272842  746666.666667             9                    0.0
#
#         Sum_Commercial_Units  Avg_Land_sqft  ...  Std_Turbidity  \
# 0                        0.0    3825.000000  ...            NaN
# 1                        3.0    2239.571429  ...            NaN
# 2                        3.0    2239.571429  ...            NaN
# 3                        3.0    2239.571429  ...            NaN
# 4                        3.0    2239.571429  ...            NaN
# ...                      ...            ...  ...            ...
# 272838                   1.0    4282.909091  ...       0.049160
# 272839                   1.0    4282.909091  ...       0.049160
# 272840                   1.0    4282.909091  ...       0.049160
# 272841                   1.0    4282.909091  ...       0.049160
# 272842                   0.0            NaN  ...       0.100167
#
#         Count_of_Turbidity_Collections  Avg_Fluoride Std_Fluoride  \
# 0                                  NaN           NaN          NaN
# 1                                  NaN           NaN          NaN
# 2                                  NaN           NaN          NaN
# 3                                  NaN           NaN          NaN
# 4                                  NaN           NaN          NaN
# ...                                ...           ...          ...
# 272838                             6.0           NaN          NaN
# 272839                             6.0           NaN          NaN
# 272840                             6.0           NaN          NaN
# 272841                             6.0           NaN          NaN
# 272842                             3.0           NaN          NaN
#
#        Count_of_Fluoride_Collections  Avg_Coliform  Std_Coliform  \
# 0                                NaN           NaN           NaN
# 1                                NaN           NaN           NaN
# 2                                NaN           NaN           NaN
# 3                                NaN           NaN           NaN
# 4                                NaN           NaN           NaN
# ...                              ...           ...           ...
# 272838                           0.0           0.0           0.0
# 272839                           0.0           0.0           0.0
# 272840                           0.0           0.0           0.0
# 272841                           0.0           0.0           0.0
# 272842                           0.0           0.0           0.0
#
#         Count_of_Coliform_Collections                 Complaint Type  \
# 0                                 NaN                            NaN
# 1                                 NaN                    Air Quality
# 2                                 NaN                       Asbestos
# 3                                 NaN               Dirty Conditions
# 4                                 NaN  General Construction/Plumbing
# ...                               ...                            ...
# 272838                            6.0                         Rodent
# 272839                            6.0                          Sewer
# 272840                            6.0           Unsanitary Condition
# 272841                            6.0                   Water System
# 272842                            3.0                Illegal Dumping
#
#         Amount of Complaints
# 0                        NaN
# 1                        6.0
# 2                        2.0
# 3                        5.0
# 4                       25.0
# ...                      ...
# 272838                   1.0
# 272839                   4.0
# 272840                   8.0
# 272841                   4.0
# 272842                   1.0
#
# [272843 rows x 29 columns]

# %% [markdown]
# ### creating the csv

# %%
df_final.to_csv(r'/Users/ale_muchinski/Library/CloudStorage/OneDrive-SharedLibraries-DanmarksTekniskeUniversitet/DTU - Projects - Documents/2. Semester/Social Data Analysis and Visualization/Project/Final Project/Data_Final_Project/ETL/Rolling Sales/df_final_4.csv', index = False)
